# %%
from interaction_inference import Dataset, Hypothesis, Minimization, Correlation
from interaction_inference import results
import numpy as np
import matplotlib.pyplot as plt
import json

# %% [markdown]
# # Load datasets to objects

# %%
# 'easy' datasets
dataset_easy_high_noInt = Dataset()
dataset_easy_high_noInt.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_easy_high_noInt.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_easy_high_noInt.csv",
    beta = 1.0
)
dataset_easy_high = Dataset()
dataset_easy_high.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_easy_high.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_easy_high.csv",
    beta = 1.0
)

dataset_easy_med_noInt = Dataset()
dataset_easy_med_noInt.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_easy_med_noInt.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_easy_med_noInt.csv",
    beta = 0.5
)
dataset_easy_med = Dataset()
dataset_easy_med.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_easy_med.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_easy_med.csv",
    beta = 0.5
)

dataset_easy_low_noInt = Dataset()
dataset_easy_low_noInt.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_easy_low_noInt.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_easy_low_noInt.csv",
    beta = 0.06
)
dataset_easy_low = Dataset()
dataset_easy_low.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_easy_low.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_easy_low.csv",
    beta = 0.06
)

# 'hard' datasets
dataset_hard_high_noInt = Dataset()
dataset_hard_high_noInt.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_hard_high_noInt.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_hard_high_noInt.csv",
    beta = 1.0
)
dataset_hard_high = Dataset()
dataset_hard_high.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_hard_high.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_hard_high.csv",
    beta = 1.0
)

dataset_hard_med_noInt = Dataset()
dataset_hard_med_noInt.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_hard_med_noInt.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_hard_med_noInt.csv",
    beta = 0.5
)
dataset_hard_med = Dataset()
dataset_hard_med.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_hard_med.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_hard_med.csv",
    beta = 0.5
)

dataset_hard_low_noInt = Dataset()
dataset_hard_low_noInt.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_hard_low_noInt.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_hard_low_noInt.csv",
    beta = 0.06
)
dataset_hard_low = Dataset()
dataset_hard_low.load_dataset(
    count_dataset_filename = "../Datasets-Easy-Hard/counts_hard_low.csv",
    param_dataset_filename = "../Datasets-Easy-Hard/params_hard_low.csv",
    beta = 0.06
)

# %% [markdown]
# # Load existing results to objects

# %% [markdown]
# ## Hypothesis results

# %%
# 'easy' datasets
hyp_easy_high_noInt = Hypothesis()
hyp_easy_high_noInt.dataset = dataset_easy_high_noInt
hyp_easy_high_noInt.result_dict = json.load(open("../Results-Easy-Hard/hyp_easy_high_noInt.json"))
hyp_easy_high = Hypothesis()
hyp_easy_high.dataset = dataset_easy_high
hyp_easy_high.result_dict = json.load(open("../Results-Easy-Hard/hyp_easy_high.json"))
'''
hyp_easy_med_noInt = Hypothesis()
hyp_easy_med_noInt.dataset = dataset_easy_med_noInt
hyp_easy_med_noInt.result_dict = json.load(open("../Results-Easy-Hard/hyp_easy_med_noInt.json"))
hyp_easy_med = Hypothesis()
hyp_easy_med.dataset = dataset_easy_med
hyp_easy_med.result_dict = json.load(open("../Results-Easy-Hard/hyp_easy_med.json"))

hyp_easy_low_noInt = Hypothesis()
hyp_easy_low_noInt.dataset = dataset_easy_low_noInt
hyp_easy_low_noInt.result_dict = json.load(open("../Results-Easy-Hard/hyp_easy_low_noInt.json"))
hyp_easy_low = Hypothesis()
hyp_easy_low.dataset = dataset_easy_low
hyp_easy_low.result_dict = json.load(open("../Results-Easy-Hard/hyp_easy_low.json"))
'''
# 'hard' datasets
hyp_hard_high_noInt = Hypothesis()
hyp_hard_high_noInt.dataset = dataset_hard_high_noInt
hyp_hard_high_noInt.result_dict = json.load(open("../Results-Easy-Hard/hyp_hard_high_noInt.json"))
hyp_hard_high = Hypothesis()
hyp_hard_high.dataset = dataset_hard_high
hyp_hard_high.result_dict = json.load(open("../Results-Easy-Hard/hyp_hard_high.json"))
'''
hyp_hard_med_noInt = Hypothesis()
hyp_hard_med_noInt.dataset = dataset_hard_med_noInt
hyp_hard_med_noInt.result_dict = json.load(open("../Results-Easy-Hard/hyp_hard_med_noInt.json"))
hyp_hard_med = Hypothesis()
hyp_hard_med.dataset = dataset_hard_med
hyp_hard_med.result_dict = json.load(open("../Results-Easy-Hard/hyp_hard_med.json"))

hyp_hard_low_noInt = Hypothesis()
hyp_hard_low_noInt.dataset = dataset_hard_low_noInt
hyp_hard_low_noInt.result_dict = json.load(open("../Results-Easy-Hard/hyp_hard_low_noInt.json"))
hyp_hard_low = Hypothesis()
hyp_hard_low.dataset = dataset_hard_low
hyp_hard_low.result_dict = json.load(open("../Results-Easy-Hard/hyp_hard_low.json"))
'''
# Out:
# '\nhyp_hard_med_noInt = Hypothesis()\nhyp_hard_med_noInt.dataset = dataset_hard_med_noInt\nhyp_hard_med_noInt.result_dict = json.load(open("../Results-Easy-Hard/hyp_hard_med_noInt.json"))\nhyp_hard_med = Hypothesis()\nhyp_hard_med.dataset = dataset_hard_med\nhyp_hard_med.result_dict = json.load(open("../Results-Easy-Hard/hyp_hard_med.json"))\n\nhyp_hard_low_noInt = Hypothesis()\nhyp_hard_low_noInt.dataset = dataset_hard_low_noInt\nhyp_hard_low_noInt.result_dict = json.load(open("../Results-Easy-Hard/hyp_hard_low_noInt.json"))\nhyp_hard_low = Hypothesis()\nhyp_hard_low.dataset = dataset_hard_low\nhyp_hard_low.result_dict = json.load(open("../Results-Easy-Hard/hyp_hard_low.json"))\n'

# %% [markdown]
# ## Minimization results

# %%
# 'easy' datasets
min_easy_high_noInt = Minimization()
min_easy_high_noInt.dataset = dataset_easy_high_noInt
min_easy_high_noInt.result_dict = json.load(open("../Results-Easy-Hard/min_easy_high_noInt.json"))
min_easy_high = Minimization()
min_easy_high.dataset = dataset_easy_high
min_easy_high.result_dict = json.load(open("../Results-Easy-Hard/min_easy_high.json"))
'''
min_easy_med_noInt = Minimization()
min_easy_med_noInt.dataset = dataset_easy_med_noInt
min_easy_med_noInt.result_dict = json.load(open("../Results-Easy-Hard/min_easy_med_noInt.json"))
min_easy_med = Minimization()
min_easy_med.dataset = dataset_easy_med
min_easy_med.result_dict = json.load(open("../Results-Easy-Hard/min_easy_med.json"))

min_easy_low_noInt = Minimization()
min_easy_low_noInt.dataset = dataset_easy_low_noInt
min_easy_low_noInt.result_dict = json.load(open("../Results-Easy-Hard/min_easy_low_noInt.json"))
min_easy_low = Minimization()
min_easy_low.dataset = dataset_easy_low
min_easy_low.result_dict = json.load(open("../Results-Easy-Hard/min_easy_low.json"))
'''
# 'hard' datasets
min_hard_high_noInt = Minimization()
min_hard_high_noInt.dataset = dataset_hard_high_noInt
min_hard_high_noInt.result_dict = json.load(open("../Results-Easy-Hard/min_hard_high_noInt.json"))
min_hard_high = Minimization()
min_hard_high.dataset = dataset_hard_high
min_hard_high.result_dict = json.load(open("../Results-Easy-Hard/min_hard_high.json"))
'''
min_hard_med_noInt = Minimization()
min_hard_med_noInt.dataset = dataset_hard_med_noInt
min_hard_med_noInt.result_dict = json.load(open("../Results-Easy-Hard/min_hard_med_noInt.json"))
min_hard_med = Minimization()
min_hard_med.dataset = dataset_hard_med
min_hard_med.result_dict = json.load(open("../Results-Easy-Hard/min_hard_med.json"))

min_hard_low_noInt = Minimization()
min_hard_low_noInt.dataset = dataset_hard_low_noInt
min_hard_low_noInt.result_dict = json.load(open("../Results-Easy-Hard/min_hard_low_noInt.json"))
min_hard_low = Minimization()
min_hard_low.dataset = dataset_hard_low
min_hard_low.result_dict = json.load(open("../Results-Easy-Hard/min_hard_low.json"))
'''
# Out:
# '\nmin_hard_med_noInt = Minimization()\nmin_hard_med_noInt.dataset = dataset_hard_med_noInt\nmin_hard_med_noInt.result_dict = json.load(open("../Results-Easy-Hard/min_hard_med_noInt.json"))\nmin_hard_med = Minimization()\nmin_hard_med.dataset = dataset_hard_med\nmin_hard_med.result_dict = json.load(open("../Results-Easy-Hard/min_hard_med.json"))\n\nmin_hard_low_noInt = Minimization()\nmin_hard_low_noInt.dataset = dataset_hard_low_noInt\nmin_hard_low_noInt.result_dict = json.load(open("../Results-Easy-Hard/min_hard_low_noInt.json"))\nmin_hard_low = Minimization()\nmin_hard_low.dataset = dataset_hard_low\nmin_hard_low.result_dict = json.load(open("../Results-Easy-Hard/min_hard_low.json"))\n'

# %% [markdown]
# ## Correlation results

# %% [markdown]
# ### One-Sided Correlation

# %%
# 'easy' datasets
pearson_one_easy_high_noInt = Correlation()
pearson_one_easy_high_noInt.dataset = dataset_easy_high_noInt
pearson_one_easy_high_noInt.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_easy_high_noInt.json"))
pearson_one_easy_high = Correlation()
pearson_one_easy_high.dataset = dataset_easy_high
pearson_one_easy_high.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_easy_high.json"))

pearson_one_easy_med_noInt = Correlation()
pearson_one_easy_med_noInt.dataset = dataset_easy_med_noInt
pearson_one_easy_med_noInt.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_easy_med_noInt.json"))
pearson_one_easy_med = Correlation()
pearson_one_easy_med.dataset = dataset_easy_med
pearson_one_easy_med.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_easy_med.json"))

pearson_one_easy_low_noInt = Correlation()
pearson_one_easy_low_noInt.dataset = dataset_easy_low_noInt
pearson_one_easy_low_noInt.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_easy_low_noInt.json"))
pearson_one_easy_low = Correlation()
pearson_one_easy_low.dataset = dataset_easy_low
pearson_one_easy_low.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_easy_low.json"))

# 'hard' datasets
pearson_one_hard_high_noInt = Correlation()
pearson_one_hard_high_noInt.dataset = dataset_hard_high_noInt
pearson_one_hard_high_noInt.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_hard_high_noInt.json"))
pearson_one_hard_high = Correlation()
pearson_one_hard_high.dataset = dataset_hard_high
pearson_one_hard_high.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_hard_high.json"))

pearson_one_hard_med_noInt = Correlation()
pearson_one_hard_med_noInt.dataset = dataset_hard_med_noInt
pearson_one_hard_med_noInt.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_hard_med_noInt.json"))
pearson_one_hard_med = Correlation()
pearson_one_hard_med.dataset = dataset_hard_med
pearson_one_hard_med.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_hard_med.json"))

pearson_one_hard_low_noInt = Correlation()
pearson_one_hard_low_noInt.dataset = dataset_hard_low_noInt
pearson_one_hard_low_noInt.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_hard_low_noInt.json"))
pearson_one_hard_low = Correlation()
pearson_one_hard_low.dataset = dataset_hard_low
pearson_one_hard_low.result_dict = json.load(open("../Results-Easy-Hard/One-Sided-Correlation/pearson_hard_low.json"))

# %% [markdown]
# ### Two-Sided Correlation

# %%
# 'easy' datasets
pearson_two_easy_high_noInt = Correlation()
pearson_two_easy_high_noInt.dataset = dataset_easy_high_noInt
pearson_two_easy_high_noInt.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_easy_high_noInt.json"))
pearson_two_easy_high = Correlation()
pearson_two_easy_high.dataset = dataset_easy_high
pearson_two_easy_high.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_easy_high.json"))

pearson_two_easy_med_noInt = Correlation()
pearson_two_easy_med_noInt.dataset = dataset_easy_med_noInt
pearson_two_easy_med_noInt.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_easy_med_noInt.json"))
pearson_two_easy_med = Correlation()
pearson_two_easy_med.dataset = dataset_easy_med
pearson_two_easy_med.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_easy_med.json"))

pearson_two_easy_low_noInt = Correlation()
pearson_two_easy_low_noInt.dataset = dataset_easy_low_noInt
pearson_two_easy_low_noInt.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_easy_low_noInt.json"))
pearson_two_easy_low = Correlation()
pearson_two_easy_low.dataset = dataset_easy_low
pearson_two_easy_low.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_easy_low.json"))

# 'hard' datasets
pearson_two_hard_high_noInt = Correlation()
pearson_two_hard_high_noInt.dataset = dataset_hard_high_noInt
pearson_two_hard_high_noInt.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_hard_high_noInt.json"))
pearson_two_hard_high = Correlation()
pearson_two_hard_high.dataset = dataset_hard_high
pearson_two_hard_high.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_hard_high.json"))

pearson_two_hard_med_noInt = Correlation()
pearson_two_hard_med_noInt.dataset = dataset_hard_med_noInt
pearson_two_hard_med_noInt.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_hard_med_noInt.json"))
pearson_two_hard_med = Correlation()
pearson_two_hard_med.dataset = dataset_hard_med
pearson_two_hard_med.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_hard_med.json"))

pearson_two_hard_low_noInt = Correlation()
pearson_two_hard_low_noInt.dataset = dataset_hard_low_noInt
pearson_two_hard_low_noInt.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_hard_low_noInt.json"))
pearson_two_hard_low = Correlation()
pearson_two_hard_low.dataset = dataset_hard_low
pearson_two_hard_low.result_dict = json.load(open("../Results-Easy-Hard/Two-Sided-Correlation/pearson_hard_low.json"))

# %% [markdown]
# # Plot results

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# ### High capture

# %%
results.multi_scatter_results(
    hyp_easy_high_noInt,
    hyp_easy_high,
    hyp_hard_high_noInt,
    hyp_hard_high,
    detailed=False
)

# %% [markdown]
# ## Minimization

# %% [markdown]
# ### High capture

# %%
results.multi_scatter_results(
    min_easy_high_noInt,
    min_easy_high,
    min_hard_high_noInt,
    min_hard_high,
    detailed=False
)

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### High capture: One vs Two sided

# %%
# all one sided high results
results.multi_scatter_results(
    pearson_one_easy_high_noInt,
    pearson_one_easy_high,
    pearson_one_hard_high_noInt,
    pearson_one_hard_high,
    detailed=False
)

# %%
# all two sided high results
results.multi_scatter_results(
    pearson_two_easy_high_noInt,
    pearson_two_easy_high,
    pearson_two_hard_high_noInt,
    pearson_two_hard_high,
    detailed=False
)

# %% [markdown]
# ### Med capture: One vs Two sided

# %%
# all one sided med results
results.multi_scatter_results(
    pearson_one_easy_med_noInt,
    pearson_one_easy_med,
    pearson_one_hard_med_noInt,
    pearson_one_hard_med,
    detailed=False
)

# %%
# all two sided med results
results.multi_scatter_results(
    pearson_two_easy_med_noInt,
    pearson_two_easy_med,
    pearson_two_hard_med_noInt,
    pearson_two_hard_med,
    detailed=False
)

# %% [markdown]
# ### Low capture: One vs Two sided

# %%
# all one sided low results
results.multi_scatter_results(
    pearson_one_easy_low_noInt,
    pearson_one_easy_low,
    pearson_one_hard_low_noInt,
    pearson_one_hard_low,
    detailed=False
)

# %%
# all two sided low results
results.multi_scatter_results(
    pearson_two_easy_low_noInt,
    pearson_two_easy_low,
    pearson_two_hard_low_noInt,
    pearson_two_hard_low,
    detailed=False
)
