# %%
import pandas as pd

# %%
data_tsv = pd.read_csv("./Datasets/vasaplate_HEK293T-mESC_split_total.UFICounts.tsv", index_col=0, sep='\t')

# %%
data_tsv.head()
# Out:
#                                       001  002  003  004  005  006  007  008  \
# ENSG00000113739_STC2_ProteinCoding      6    0   40    0   28    1    5    0
# ENSG00000188342_GTF2F2_ProteinCoding    7    0   11    0   38    0    7    1
# ENSG00000115977_AAK1_ProteinCoding     12    0   17    1   28    0    1    2
# ENSG00000114648_KLHL18_ProteinCoding    5    0   10    1   38    0    3    0
# ENSG00000100316_RPL3_ProteinCoding     20    0   66    3  412    1   60    6
#
#                                       009  010  ...  375  376  377  378  379  \
# ENSG00000113739_STC2_ProteinCoding      0    0  ...   12    1   15    0   48
# ENSG00000188342_GTF2F2_ProteinCoding    0    0  ...   26    1   12    2   50
# ENSG00000115977_AAK1_ProteinCoding      0    0  ...   13    2   20    2   45
# ENSG00000114648_KLHL18_ProteinCoding    0    0  ...   24    3    5    0   25
# ENSG00000100316_RPL3_ProteinCoding      1    0  ...  148    5   87    3  254
#
#                                       380  381  382  383  384
# ENSG00000113739_STC2_ProteinCoding      0   57    0    1    0
# ENSG00000188342_GTF2F2_ProteinCoding    1   64    0    0    0
# ENSG00000115977_AAK1_ProteinCoding      0   42    0    1    0
# ENSG00000114648_KLHL18_ProteinCoding    0   45    0    0    0
# ENSG00000100316_RPL3_ProteinCoding      2  313    2    8    1
#
# [5 rows x 384 columns]

# %%
data_cleaned_tsv = data_tsv[data_tsv.max(axis=1) > 0]

# %%
data_cleaned_tsv.head()
# Out:
#                                       001  002  003  004  005  006  007  008  \
# ENSG00000113739_STC2_ProteinCoding      6    0   40    0   28    1    5    0
# ENSG00000188342_GTF2F2_ProteinCoding    7    0   11    0   38    0    7    1
# ENSG00000115977_AAK1_ProteinCoding     12    0   17    1   28    0    1    2
# ENSG00000114648_KLHL18_ProteinCoding    5    0   10    1   38    0    3    0
# ENSG00000100316_RPL3_ProteinCoding     20    0   66    3  412    1   60    6
#
#                                       009  010  ...  375  376  377  378  379  \
# ENSG00000113739_STC2_ProteinCoding      0    0  ...   12    1   15    0   48
# ENSG00000188342_GTF2F2_ProteinCoding    0    0  ...   26    1   12    2   50
# ENSG00000115977_AAK1_ProteinCoding      0    0  ...   13    2   20    2   45
# ENSG00000114648_KLHL18_ProteinCoding    0    0  ...   24    3    5    0   25
# ENSG00000100316_RPL3_ProteinCoding      1    0  ...  148    5   87    3  254
#
#                                       380  381  382  383  384
# ENSG00000113739_STC2_ProteinCoding      0   57    0    1    0
# ENSG00000188342_GTF2F2_ProteinCoding    1   64    0    0    0
# ENSG00000115977_AAK1_ProteinCoding      0   42    0    1    0
# ENSG00000114648_KLHL18_ProteinCoding    0   45    0    0    0
# ENSG00000100316_RPL3_ProteinCoding      2  313    2    8    1
#
# [5 rows x 384 columns]

# %%
data_cleaned_tsv.shape
# Out:
# (389528, 384)

# %%
[
    name for name in list(data_cleaned_tsv.index)
    if "ProteinCoding" not in name
    and "snoRNA" not in name
    and "lncRNA" not in name
    and "TranscribedUnprocessedPseudogene" not in name
    and "TranscribedProcessedPseudogene" not in name
    and "UnprocessedPseudogene" not in name
    and "ProcessedPseudogene" not in name
    and "PolymorphicPseudogene" not in name
    and "TranscribedUnitaryPseudogene" not in name
    and "UnitaryPseudogene" not in name
    and "ribozyme" not in name
    and "scaRNA" not in name
    and "snRNA" not in name
    and "MiscRna" not in name
    and "miRNA" not in name
    and "MtRrna" not in name
    and "tRNA" not in name 
    and "pseudogene" not in name
    and "Pseudogene" not in name
    and "scRNA" not in name
    and "rRNA" not in name
    and "MtTrna" not in name
    and "IgVGene" not in name
    and "TrVGene" not in name
    and "IgCGene" not in name
    and "TrCGene" not in name
]
# Out:
# []

# %% [markdown]
# ## Coding genes

# %%
data_coding = data_cleaned_tsv.loc[[name for name in list(data_cleaned_tsv.index) if "ProteinCoding" in name]]

# %%
data_coding.head()
# Out:
#                                       001  002  003  004  005  006  007  008  \
# ENSG00000113739_STC2_ProteinCoding      6    0   40    0   28    1    5    0
# ENSG00000188342_GTF2F2_ProteinCoding    7    0   11    0   38    0    7    1
# ENSG00000115977_AAK1_ProteinCoding     12    0   17    1   28    0    1    2
# ENSG00000114648_KLHL18_ProteinCoding    5    0   10    1   38    0    3    0
# ENSG00000100316_RPL3_ProteinCoding     20    0   66    3  412    1   60    6
#
#                                       009  010  ...  375  376  377  378  379  \
# ENSG00000113739_STC2_ProteinCoding      0    0  ...   12    1   15    0   48
# ENSG00000188342_GTF2F2_ProteinCoding    0    0  ...   26    1   12    2   50
# ENSG00000115977_AAK1_ProteinCoding      0    0  ...   13    2   20    2   45
# ENSG00000114648_KLHL18_ProteinCoding    0    0  ...   24    3    5    0   25
# ENSG00000100316_RPL3_ProteinCoding      1    0  ...  148    5   87    3  254
#
#                                       380  381  382  383  384
# ENSG00000113739_STC2_ProteinCoding      0   57    0    1    0
# ENSG00000188342_GTF2F2_ProteinCoding    1   64    0    0    0
# ENSG00000115977_AAK1_ProteinCoding      0   42    0    1    0
# ENSG00000114648_KLHL18_ProteinCoding    0   45    0    0    0
# ENSG00000100316_RPL3_ProteinCoding      2  313    2    8    1
#
# [5 rows x 384 columns]

# %%
data_coding.shape
# Out:
# (316369, 384)

# %% [markdown]
# ## Non-coding genes

# %%
data_miRNA = data_cleaned_tsv.loc[[name for name in list(data_cleaned_tsv.index) if "miRNA" in name]]

# %%
data_miRNA.head()
# Out:
#                                                     001  002  003  004  005  \
# ENSG00000207652_MIR621_miRNA                          1    0    0    0    0
# ENSG00000274620_MIR378J_miRNA                         1    0    0    0    0
# ENSG00000265828_MIR3939_miRNA                         1    0    0    0    0
# ENSG00000283803_MIR3198.2_miRNA                       1    0    0    0    0
# ENSG00000265735_RN7SL5P_MiscRna-ENSG00000274012...    2    2    6    5   93
#
#                                                     006  007  008  009  010  \
# ENSG00000207652_MIR621_miRNA                          0    0    0    0    0
# ENSG00000274620_MIR378J_miRNA                         0    0    0    0    0
# ENSG00000265828_MIR3939_miRNA                         0    0    0    0    0
# ENSG00000283803_MIR3198.2_miRNA                       0    0    0    0    0
# ENSG00000265735_RN7SL5P_MiscRna-ENSG00000274012...    4   39    9    0    1
#
#                                                     ...  375  376  377  378  \
# ENSG00000207652_MIR621_miRNA                        ...    0    0    0    0
# ENSG00000274620_MIR378J_miRNA                       ...    0    0    0    0
# ENSG00000265828_MIR3939_miRNA                       ...    0    0    0    0
# ENSG00000283803_MIR3198.2_miRNA                     ...    0    0    0    0
# ENSG00000265735_RN7SL5P_MiscRna-ENSG00000274012...  ...    9   32    6    5
#
#                                                     379  380  381  382  383  \
# ENSG00000207652_MIR621_miRNA                          0    0    0    0    0
# ENSG00000274620_MIR378J_miRNA                         0    0    0    0    0
# ENSG00000265828_MIR3939_miRNA                         0    0    0    0    0
# ENSG00000283803_MIR3198.2_miRNA                       0    0    1    0    0
# ENSG00000265735_RN7SL5P_MiscRna-ENSG00000274012...   69    0   30    1   15
#
#                                                     384
# ENSG00000207652_MIR621_miRNA                          0
# ENSG00000274620_MIR378J_miRNA                         0
# ENSG00000265828_MIR3939_miRNA                         0
# ENSG00000283803_MIR3198.2_miRNA                       0
# ENSG00000265735_RN7SL5P_MiscRna-ENSG00000274012...    0
#
# [5 rows x 384 columns]

# %%
data_miRNA.shape
# Out:
# (701, 384)

# %%
data_lncRNA = data_cleaned_tsv.loc[[name for name in list(data_cleaned_tsv.index) if "lncRNA" in name]]

# %%
data_lncRNA.head()
# Out:
#                                    001  002  003  004  005  006  007  008  \
# ENSG00000163597_SNHG16_lncRNA       19    0    1    3  155    2   11    2
# ENSG00000242125_SNHG3_lncRNA         6    1    6    0   92    2    6    2
# ENSG00000260417_AC092127.1_lncRNA    1    0    0    0    1    1    0    0
# ENSG00000250903_GMDS.DT_lncRNA       2    0   25    1   20    0    3    0
# ENSG00000268205_AC005261.2_lncRNA    2    0    4    0    3    0    1    1
#
#                                    009  010  ...  375  376  377  378  379  \
# ENSG00000163597_SNHG16_lncRNA        0    2  ...   52    3   30    1  106
# ENSG00000242125_SNHG3_lncRNA         0    0  ...   36    4   16    1   23
# ENSG00000260417_AC092127.1_lncRNA    0    0  ...    0    0    0    0    0
# ENSG00000250903_GMDS.DT_lncRNA       0    0  ...    3    2    7    0   61
# ENSG00000268205_AC005261.2_lncRNA    0    0  ...    2    0    5    0    6
#
#                                    380  381  382  383  384
# ENSG00000163597_SNHG16_lncRNA        1  147    1    5    0
# ENSG00000242125_SNHG3_lncRNA         0   45    0    1    1
# ENSG00000260417_AC092127.1_lncRNA    0    0    0    0    0
# ENSG00000250903_GMDS.DT_lncRNA       0   17    0    1    0
# ENSG00000268205_AC005261.2_lncRNA    0    0    0    0    0
#
# [5 rows x 384 columns]

# %%
data_lncRNA.shape
# Out:
# (134224, 384)
