# %%
import pandas as pd
import json

# %% [markdown]
# ## Data loading

# %%
# load counts
data_FIB = pd.read_csv("../../Moment-equations/Real-Data-2/Data/GSE151334_FIB_counts_thresh.csv", index_col=0)

# load RNA types
biotypes_dict = json.load(open("../../Moment-equations/Real-Data-2/Biotypes/biotypes_FIB.json"))

# select indices of protein coding mRNA and non-coding miRNA
pcRNA_indices = [idx for idx, btype in enumerate(biotypes_dict.values()) if btype == "protein_coding"]
miRNA_indices = [idx for idx, btype in enumerate(biotypes_dict.values()) if btype == "miRNA"]

# select protein coding genes
data_FIB_pcRNA_NB = data_FIB.iloc[pcRNA_indices]

# select miRNA
data_FIB_miRNA_NB = data_FIB.iloc[miRNA_indices]

# %%
# load independent MF results
MF_ind_df = pd.read_csv("./Results/independent_MF_concat.csv", index_col=0)

# %% [markdown]
# ## Running

# %%
# miRNA
miRNA_list_NB = data_FIB_miRNA_NB.index

# phases
phases_NB = ["All", "G1", "S", "G2M"]

# method confidence (on output correlation intervals)
method_confidence_NB = ["95", "100"]
method_confidence_string_NB = " ".join(method_confidence_NB)

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[0]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR100
# ...
# 100%|██████████| 1232/1232 [15:02<00:00,  1.37it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[1]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR103A2
# ...
# 100%|██████████| 1999/1999 [22:05<00:00,  1.51it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[2]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR16-2
# ...
# 100%|██████████| 355/355 [03:57<00:00,  1.50it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[3]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR199A1
# ...
# 100%|██████████| 1883/1883 [22:31<00:00,  1.39it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[4]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR199A2
# ...
# 100%|██████████| 795/795 [08:40<00:00,  1.53it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[5]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR221
# ...
# 100%|██████████| 645/645 [06:59<00:00,  1.54it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[6]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR222
# ...
# 100%|██████████| 24/24 [00:19<00:00,  1.24it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[7]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR23A
# ...
# 100%|██████████| 134/134 [01:52<00:00,  1.20it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[8]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR24-2
# ...
# 100%|██████████| 319/319 [03:30<00:00,  1.52it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[9]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR27A
# ...
# 100%|██████████| 131/131 [01:26<00:00,  1.51it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[10]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR29A
# ...
# 100%|██████████| 1169/1169 [12:23<00:00,  1.57it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[11]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR31
# ...
# 100%|██████████| 834/834 [08:51<00:00,  1.57it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[12]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR3609
# ...
# 100%|██████████| 947/947 [10:03<00:00,  1.57it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[13]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR4449
# ...
# 100%|██████████| 373/373 [07:13<00:00,  1.16s/it]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[14]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR6087
# ...
# 100%|██████████| 103/103 [02:28<00:00,  1.44s/it]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[15]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR877
# ...
# 100%|██████████| 329/329 [06:50<00:00,  1.25s/it]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[16]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIRLET7A1
# ...
# 100%|██████████| 1057/1057 [12:38<00:00,  1.39it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[17]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIRLET7A2
# ...
# 100%|██████████| 1216/1216 [13:38<00:00,  1.49it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[18]
print(f"miRNA {miRNA_NB}")

# for each phase
for phase_NB in phases_NB:

    # select interacting mRNA
    mRNA_NB = MF_ind_df.index[MF_ind_df[f"{miRNA_NB}_{phase_NB}_d3_c95_status"] == "INFEASIBLE"]
    mRNA_string_NB = " ".join(list(mRNA_NB))

    # run
    outfile_NB = f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv"
    #%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIRLET7D
# ...
# 100%|██████████| 188/188 [02:10<00:00,  1.44it/s]

# %% [markdown]
# ## Concat

# %%
# load result files
df_list = []
for miRNA_NB in data_FIB_miRNA_NB.index:
    for phase_NB in phases_NB:
        try:
            df = pd.read_csv(f"./Results/Script-Outfiles/int_MF_{miRNA_NB}_{phase_NB}.csv", index_col=0)
            df_list.append(df)
        except FileNotFoundError:
            pass

# concat
df_concat = pd.concat(df_list, axis="columns")

# save
#df_concat.to_csv("./Results/interacting_MF_concat.csv")

# %%
df_concat#.head()
# Out:
#          MIR100_All_d3_N1000_c95_mc95_HAR_min  \
# AARS2                               -0.725809
# ABCA6                               -0.912242
# ABCC10                              -0.642890
# ABHD12                              -0.284425
# ABHD14B                             -0.316026
# ...                                       ...
# ST13                                      NaN
# TARDBP                                    NaN
# TUSC3                                     NaN
# WWTR1                                     NaN
# TCOF1                                     NaN
#
#          MIR100_All_d3_N1000_c95_mc95_HAR_max  \
# AARS2                               -0.126335
# ABCA6                               -0.186952
# ABCC10                              -0.108086
# ABHD12                              -0.060628
# ABHD14B                             -0.096861
# ...                                       ...
# ST13                                      NaN
# ...

# %%
19 * 4 * 4
# Out:
# 304

# %% [markdown]
# # Appendix

# %%
# load Real-Data-2 independent MF results
OLD_independent_MF_df = pd.read_csv("../../Moment-equations/Real-Data-2/Results/independent_MF.csv", index_col=0)

# %%
# miRNA
miRNA_list_NB = data_FIB_miRNA_NB.index

# method confidence (on output correlation intervals)
method_confidence_NB = ["95", "100"]
method_confidence_string_NB = " ".join(method_confidence_NB)

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[6]
print(f"miRNA {miRNA_NB}")

# all cells
phase_NB = "All"

# select d = 4 interacting mRNA
mRNA_NB = OLD_independent_MF_df.index[OLD_independent_MF_df[f"{miRNA_NB}_d4_c95_status"] == "INFEASIBLE"]
mRNA_string_NB = " ".join(list(mRNA_NB))

# still use d = 3 to optimize (d = 4 caused lots of infeasibility, still some issues)
d_NB = 3

# run
outfile_NB = f"./Results/Script-Testing/int_MF_{miRNA_NB}_All.csv"
#%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --d {d_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR222
# ...
#  36%|███▌      | 214/601 [02:32<04:28,  1.44it/s]Traceback (most recent call last):
#   File "c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\SDP_interaction_inference\optimization_MOSEK.py", line 110, in analyse_dataset
#     feasible_points_HAR, t_int_err, t_int_eps = self.hit_and_run(i, feasible_points[0])
# IndexError: list index out of range
# Optimization failed: list index out of range
#  43%|████▎     | 257/601 [03:02<04:14,  1.35it/s]Traceback (most recent call last):
#   File "c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\SDP_interaction_inference\optimization_MOSEK.py", line 110, in analyse_dataset
#     feasible_points_HAR, t_int_err, t_int_eps = self.hit_and_run(i, feasible_points[0])
# IndexError: list index out of range
# Optimization failed: list index out of range
#  44%|████▍     | 266/601 [03:08<04:08,  1.35it/s]Traceback (most recent call last):
# ...

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[7]
print(f"miRNA {miRNA_NB}")

# all cells
phase_NB = "All"

# select d = 4 interacting mRNA
mRNA_NB = OLD_independent_MF_df.index[OLD_independent_MF_df[f"{miRNA_NB}_d4_c95_status"] == "INFEASIBLE"]
mRNA_string_NB = " ".join(list(mRNA_NB))

# still use d = 3 to optimize (d = 4 caused lots of infeasibility, still some issues)
d_NB = 3

# run
outfile_NB = f"./Results/Script-Testing/int_MF_{miRNA_NB}_All.csv"
#%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --d {d_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR23A
# ...
#  40%|████      | 325/809 [04:02<06:00,  1.34it/s]Traceback (most recent call last):
#   File "c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\SDP_interaction_inference\optimization_MOSEK.py", line 110, in analyse_dataset
#     feasible_points_HAR, t_int_err, t_int_eps = self.hit_and_run(i, feasible_points[0])
# IndexError: list index out of range
# Optimization failed: list index out of range
#  46%|████▌     | 373/809 [04:36<05:22,  1.35it/s]Traceback (most recent call last):
#   File "c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\SDP_interaction_inference\optimization_MOSEK.py", line 110, in analyse_dataset
#     feasible_points_HAR, t_int_err, t_int_eps = self.hit_and_run(i, feasible_points[0])
# IndexError: list index out of range
# Optimization failed: list index out of range
# 100%|██████████| 809/809 [09:58<00:00,  1.35it/s]

# %%
# select miRNA
miRNA_NB = miRNA_list_NB[15]
print(f"miRNA {miRNA_NB}")

# all cells
phase_NB = "All"

# select d = 4 interacting mRNA
mRNA_NB = OLD_independent_MF_df.index[OLD_independent_MF_df[f"{miRNA_NB}_d4_c95_status"] == "INFEASIBLE"]
mRNA_string_NB = " ".join(list(mRNA_NB))

# still use d = 3 to optimize (d = 4 caused lots of infeasibility, still some issues)
d_NB = 3

# run
outfile_NB = f"./Results/Script-Testing/int_MF_{miRNA_NB}_All.csv"
#%run -i interacting_MF_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --d {d_NB} --method_confidence {method_confidence_string_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR877
# ...
#  40%|████      | 444/1104 [05:33<08:15,  1.33it/s]Traceback (most recent call last):
#   File "c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\SDP_interaction_inference\optimization_MOSEK.py", line 110, in analyse_dataset
#     feasible_points_HAR, t_int_err, t_int_eps = self.hit_and_run(i, feasible_points[0])
# IndexError: list index out of range
# Optimization failed: list index out of range
#  46%|████▋     | 512/1104 [06:24<07:24,  1.33it/s]Traceback (most recent call last):
#   File "c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\SDP_interaction_inference\optimization_MOSEK.py", line 110, in analyse_dataset
#     feasible_points_HAR, t_int_err, t_int_eps = self.hit_and_run(i, feasible_points[0])
# IndexError: list index out of range
# Optimization failed: list index out of range
# 100%|██████████| 1104/1104 [13:46<00:00,  1.34it/s]
