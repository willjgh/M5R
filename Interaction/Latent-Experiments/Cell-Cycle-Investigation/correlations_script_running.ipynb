# %%
import pandas as pd
import json

# %% [markdown]
# ## Data loading

# %%
# load counts
data_FIB = pd.read_csv("../../Moment-equations/Real-Data-2/Data/GSE151334_FIB_counts_thresh.csv", index_col=0)

# load RNA types
biotypes_dict = json.load(open("../../Moment-equations/Real-Data-2/Biotypes/biotypes_FIB.json"))

# select indices of protein coding mRNA and non-coding miRNA
pcRNA_indices = [idx for idx, btype in enumerate(biotypes_dict.values()) if btype == "protein_coding"]
miRNA_indices = [idx for idx, btype in enumerate(biotypes_dict.values()) if btype == "miRNA"]

# select protein coding genes
data_FIB_pcRNA_NB = data_FIB.iloc[pcRNA_indices]

# select miRNA
data_FIB_miRNA_NB = data_FIB.iloc[miRNA_indices]

# %% [markdown]
# ## Running

# %%
# mRNA
G = 10000
mRNA_NB = data_FIB_pcRNA_NB.index[:G]
mRNA_string_NB = " ".join(list(mRNA_NB))

# miRNA
miRNA_list_NB = data_FIB_miRNA_NB.index

# phases
phases_NB = ["All", "G1", "S", "G2M"]

# %%
miRNA_NB = miRNA_list_NB[0]
print(f"miRNA {miRNA_NB}")
for phase_NB in phases_NB:
    outfile_NB = f"./Results/Script-Outfiles/corr_{miRNA_NB}_{phase_NB}.csv"
    #%run -i correlations_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR100
# 100%|██████████| 9296/9296 [01:19<00:00, 117.05it/s]
# 100%|██████████| 9296/9296 [01:07<00:00, 138.56it/s]
#   2%|▏         | 175/9296 [00:00<00:10, 848.21it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:12<00:00, 763.54it/s]
# 100%|██████████| 9296/9296 [00:11<00:00, 785.94it/s]
#  10%|▉         | 924/9296 [00:02<00:22, 370.62it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:23<00:00, 389.05it/s]
# 100%|██████████| 9296/9296 [00:24<00:00, 386.38it/s]
# 100%|██████████| 9296/9296 [00:41<00:00, 224.92it/s]
# 100%|██████████| 9296/9296 [00:40<00:00, 227.46it/s]

# %%
miRNA_NB = miRNA_list_NB[1]
print(f"miRNA {miRNA_NB}")
for phase_NB in phases_NB:
    outfile_NB = f"./Results/Script-Outfiles/corr_{miRNA_NB}_{phase_NB}.csv"
    #%run -i correlations_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR103A2
# 100%|██████████| 9296/9296 [01:12<00:00, 128.21it/s]
# 100%|██████████| 9296/9296 [01:06<00:00, 140.83it/s]
#   1%|▏         | 135/9296 [00:00<00:14, 653.47it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:11<00:00, 793.20it/s]
# 100%|██████████| 9296/9296 [00:11<00:00, 779.17it/s]
#  10%|▉         | 923/9296 [00:03<00:26, 321.71it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:27<00:00, 341.91it/s]
# 100%|██████████| 9296/9296 [00:27<00:00, 333.53it/s]
# 100%|██████████| 9296/9296 [00:29<00:00, 311.25it/s]
# 100%|██████████| 9296/9296 [00:31<00:00, 290.99it/s]

# %%
miRNA_NB = miRNA_list_NB[2]
print(f"miRNA {miRNA_NB}")
for phase_NB in phases_NB:
    outfile_NB = f"./Results/Script-Outfiles/corr_{miRNA_NB}_{phase_NB}.csv"
    #%run -i correlations_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR16-2
# 100%|██████████| 9296/9296 [01:31<00:00, 101.23it/s]
# 100%|██████████| 9296/9296 [01:07<00:00, 136.78it/s]
#   2%|▏         | 166/9296 [00:00<00:11, 786.09it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:18<00:00, 512.03it/s]
# 100%|██████████| 9296/9296 [00:18<00:00, 511.77it/s]
#  10%|█         | 954/9296 [00:03<00:39, 209.62it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:27<00:00, 338.50it/s]
# 100%|██████████| 9296/9296 [00:21<00:00, 441.98it/s]
# 100%|██████████| 9296/9296 [00:25<00:00, 370.13it/s]
# 100%|██████████| 9296/9296 [00:35<00:00, 264.46it/s]

# %%
miRNA_NB = miRNA_list_NB[3]
print(f"miRNA {miRNA_NB}")
for phase_NB in phases_NB:
    outfile_NB = f"./Results/Script-Outfiles/corr_{miRNA_NB}_{phase_NB}.csv"
    #%run -i correlations_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --outfile {outfile_NB}
# Out:
# miRNA MIR199A1
# 100%|██████████| 9296/9296 [01:09<00:00, 133.02it/s]
# 100%|██████████| 9296/9296 [00:59<00:00, 157.02it/s]
#   2%|▏         | 171/9296 [00:00<00:10, 851.21it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:10<00:00, 857.16it/s]
# 100%|██████████| 9296/9296 [00:10<00:00, 889.05it/s]
#  10%|█         | 948/9296 [00:02<00:18, 443.29it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00
/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:22<00:00, 412.35it/s]
# 100%|██████████| 9296/9296 [00:22<00:00, 406.86it/s]
# 100%|██████████| 9296/9296 [00:27<00:00, 343.27it/s]
# 100%|██████████| 9296/9296 [00:27<00:00, 332.90it/s]

# %%
miRNA_NB = miRNA_list_NB[17]
print(f"miRNA {miRNA_NB}")
for phase_NB in phases_NB:
    outfile_NB = f"./Results/Script-Outfiles/corr_{miRNA_NB}_{phase_NB}.csv"
    #%run -i correlations_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --outfile {outfile_NB}
# Out:
# miRNA MIRLET7A2
# 100%|██████████| 9296/9296 [01:01<00:00, 150.09it/s]
# 100%|██████████| 9296/9296 [01:02<00:00, 148.51it/s]
#   1%|          | 91/9296 [00:00<00:10, 905.02it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:11<00:00, 826.74it/s]
# 100%|██████████| 9296/9296 [00:11<00:00, 815.73it/s]
#  10%|█         | 930/9296 [00:02<00:19, 421.79it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:23<00:00, 390.53it/s]
# 100%|██████████| 9296/9296 [00:23<00:00, 403.70it/s]
# 100%|██████████| 9296/9296 [00:28<00:00, 328.25it/s]
# 100%|██████████| 9296/9296 [00:28<00:00, 329.65it/s]

# %%
miRNA_NB = miRNA_list_NB[18]
print(f"miRNA {miRNA_NB}")
for phase_NB in phases_NB:
    outfile_NB = f"./Results/Script-Outfiles/corr_{miRNA_NB}_{phase_NB}.csv"
    #%run -i correlations_script.py --miRNA {miRNA_NB} --mRNA {mRNA_string_NB} --phase {phase_NB} --outfile {outfile_NB}
# Out:
# miRNA MIRLET7D
# 100%|██████████| 9296/9296 [01:02<00:00, 147.92it/s]
# 100%|██████████| 9296/9296 [01:02<00:00, 147.98it/s]
#   2%|▏         | 166/9296 [00:00<00:11, 773.01it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:11<00:00, 823.83it/s]
# 100%|██████████| 9296/9296 [00:11<00:00, 824.21it/s]
#  10%|█         | 930/9296 [00:02<00:20, 415.76it/s]c:\Users\willi\Documents\ProjectPaper\M5R_venv\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1601: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# 100%|██████████| 9296/9296 [00:22<00:00, 405.47it/s]
# 100%|██████████| 9296/9296 [00:23<00:00, 402.48it/s]
# 100%|██████████| 9296/9296 [00:28<00:00, 331.91it/s]
# 100%|██████████| 9296/9296 [00:28<00:00, 331.52it/s]

# %% [markdown]
# ## Concat

# %%
# load result files
df_list = []
for miRNA_NB in data_FIB_miRNA_NB.index:
    for phase_NB in phases_NB:
        try:
            df = pd.read_csv(f"./Results/Script-Outfiles/corr_{miRNA_NB}_{phase_NB}.csv", index_col=0)
            df_list.append(df)
        except FileNotFoundError:
            pass

# concat
df_concat = pd.concat(df_list, axis="columns")

# save
#df_concat.to_csv("./Results/corr_concat.csv")

# %%
df_concat#.head()
# Out:
#         MIR100_All_c95_OB  MIR100_All_c95_OB_min  MIR100_All_c95_OB_max  \
# A4GALT           0.017344              -0.034446               0.139737
# AAAS             0.067788              -0.024565               0.216725
# AACS             0.147775              -0.012140               0.380490
# AADAT           -0.027420              -0.075987               0.057661
# AAGAB            0.209310              -0.081758               0.489068
# ...                   ...                    ...                    ...
# ZXDC             0.052729              -0.034260               0.197181
# ZYG11B           0.333258               0.083709               0.505879
# ZYX             -0.016780              -0.091407               0.093982
# ZZEF1           -0.017684              -0.065740               0.074753
# ZZZ3            -0.067078              -0.104817              -0.027159
#
#         MIR100_All_c95_AL  MIR100_All_c95_AL_min  MIR100_All_c95_AL_max  \
# A4GALT          -0.002952              -0.058064               0.150397
# AAAS             0.032127              -0.066211               0.193183
# AACS             0.117994              -0.050079               0.355957
# AADAT           -0.063652              -0.124915               0.023102
# AAGAB            0.184931              -0.145260               0.478824
# ...                   ...                    ...                    ...
# ZXDC             0.031438              -0.063914               0.173915
# ZYG11B           0.313979               0.035627               0.495773
# ZYX             -0.111041              -0.213559               0.018657
# ZZEF1           -0.064988              -0.128911               0.030481
# ZZZ3            -0.125794              -0.186501              -0.081954
#
#         MIR100_G1_c95_OB  MIR100_G1_c95_OB_min  MIR100_G1_c95_OB_max  \
# A4GALT          0.540264             -0.105192              0.967099
# AAAS            0.024854             -0.076923              0.620875
# AACS            0.109901             -0.174522              0.674335
# AADAT           0.323491             -0.176741              0.756395
# AAGAB          -0.082916             -0.220603              0.382035
# ...                  ...                   ...                   ...
# ZXDC           -0.091053             -0.173261             -0.056563
# ZYG11B         -0.072441             -0.183458              0.167275
# ZYX             0.175772             -0.257234              0.426972
# ZZEF1          -0.045253             -0.175299              0.461788
# ZZZ3            0.178247              0.027063              0.613055
#
#         MIR100_G1_c95_AL  ...  MIRLET7D_S_c95_OB_max  MIRLET7D_S_c95_AL  \
# A4GALT          0.569574  ...               0.266751          -0.017093
# AAAS            0.005031  ...               0.078888          -0.136962
# AACS            0.082538  ...               0.102915          -0.147962
# AADAT           0.322579  ...               0.107755          -0.105896
# AAGAB          -0.163413  ...               0.108356          -0.135824
# ...                  ...  ...                    ...                ...
# ZXDC           -0.136197  ...               0.071621          -0.093385
# ZYG11B         -0.135716  ...               0.226278          -0.112459
# ZYX             0.112661  ...               0.543744           0.127973
# ZZEF1          -0.127270  ...               0.442973           0.076446
# ZZZ3            0.154056  ...               0.253983          -0.056972
#
#         MIRLET7D_S_c95_AL_min  MIRLET7D_S_c95_AL_max  MIRLET7D_G2M_c95_OB  \
# A4GALT              -0.218663               0.259463             0.016993
# AAAS                -0.351379               0.013968             0.036859
# AACS                -0.283782               0.027592             0.175340
# AADAT               -0.225293               0.039398            -0.120312
# AAGAB               -0.250979               0.032261             0.334920
# ...                       ...                    ...                  ...
# ZXDC                -0.190568               0.021998             0.113326
# ZYG11B              -0.287559               0.168780             0.444415
# ZYX                 -0.262415               0.524439             0.003431
# ZZEF1               -0.220849               0.440844             0.048836
# ZZZ3                -0.193560               0.187052            -0.031978
#
#         MIRLET7D_G2M_c95_OB_min  MIRLET7D_G2M_c95_OB_max  MIRLET7D_G2M_c95_AL  \
# A4GALT                -0.134008                 0.114699            -0.027936
# AAAS                  -0.096296                 0.228195            -0.078228
# AACS                  -0.008092                 0.378634             0.102499
# AADAT                 -0.185525                -0.054353            -0.235310
# AAGAB                 -0.063998                 0.632261             0.290783
# ...                         ...                      ...                  ...
# ZXDC                  -0.048160                 0.489274             0.068712
# ZYG11B                 0.058537                 0.660651             0.395654
# ZYX                   -0.155960                 0.241817            -0.292774
# ZZEF1                 -0.056434                 0.252432            -0.047519
# ZZZ3                  -0.192363                 0.142795            -0.185689
#
#         MIRLET7D_G2M_c95_AL_min  MIRLET7D_G2M_c95_AL_max
# A4GALT                -0.281820                 0.078794
# AAAS                  -0.243834                 0.154311
# AACS                  -0.104194                 0.367370
# AADAT                 -0.376124                -0.144213
# AAGAB                 -0.212976                 0.629408
# ...                         ...                      ...
# ZXDC                  -0.142608                 0.519286
# ZYG11B                -0.146027                 0.654021
# ZYX                   -0.543510                -0.026878
# ZZEF1                 -0.184672                 0.175393
# ZZZ3                  -0.447336                 0.026495
#
# [9296 rows x 456 columns]

# %%
# 19 miRNA, 4 sets of cells (all, G1, S, G2M), 6 results (point, lb, ub for OB, AL)
19 * 4 * 6
# Out:
# 456

# %% [markdown]
# ## Vectorized Speedup

# %%
import numpy as np

# %%
g = 10

x1 = data_FIB_pcRNA_NB.iloc[g].values
x2 = data_FIB_miRNA_NB.iloc[0].values

sample = np.vstack([x1, x2]).T

beta = np.ones(sample.shape[0])

# %%
def correlation_bootstrap_sample(sample, beta, confidence=None, resamples=None):

    # get sample size
    n = sample.shape[0]

    # get bootstrap size: default to sample size
    if resamples is None:
        resamples = n
    # confidence level: default to 95%
    if confidence is None:
        confidence = 0.95

    # bootstrap to N x n x 2 array
    boot = rng.choice(sample, size=(resamples, n))

    # capture moments
    E_beta = np.mean(beta)
    E_beta2 = np.mean(beta**2)

    # compute correlations
    estimates = np.zeros(resamples)

    b1 = boot[:, :, 0]
    b2 = boot[:, :, 1]

    # OB moments
    E_xy_OB = np.mean(b1 * b2, axis=1)
    E_x_OB = np.mean(b1, axis=1)
    E_y_OB = np.mean(b2, axis=1)
    E_x2_OB = np.mean(b1**2, axis=1)
    E_y2_OB = np.mean(b2**2, axis=1)

    # OG moments
    E_xy_OG = E_xy_OB / E_beta2
    E_x_OG = E_x_OB / E_beta
    E_y_OG = E_y_OB / E_beta
    E_x2_OG = (1 / E_beta2)*E_x2_OB + (1 / E_beta)*E_x_OB - (1 / E_beta2)*E_x_OB
    E_y2_OG = (1 / E_beta2)*E_y2_OB + (1 / E_beta)*E_y_OB - (1 / E_beta2)*E_y_OB

    varx_OG = E_x2_OG - E_x_OG**2
    vary_OG = E_y2_OG - E_y_OG**2

    mask = (varx_OG > 0.0) & (vary_OG > 0.0)
    estimates[~mask] = np.nan
    estimates[mask] = (E_xy_OG[mask] - E_x_OG[mask]*E_y_OG[mask]) / (np.sqrt(varx_OG[mask]) * np.sqrt(vary_OG[mask]))

    # take quantiles
    alpha = 1 - confidence
    interval = np.nanquantile(estimates, [(alpha / 2), 1 - (alpha / 2)])

    # compute point estimate from original sample
    b1 = sample[:, 0]
    b2 = sample[:, 1]

    # OB moments
    E_xy_OB = np.mean(b1 * b2)
    E_x_OB = np.mean(b1)
    E_y_OB = np.mean(b2)
    E_x2_OB = np.mean(b1**2)
    E_y2_OB = np.mean(b2**2)

    # OG moments
    E_xy_OG = E_xy_OB / E_beta2
    E_x_OG = E_x_OB / E_beta
    E_y_OG = E_y_OB / E_beta
    E_x2_OG = (1 / E_beta2)*E_x2_OB + (1 / E_beta)*E_x_OB - (1 / E_beta2)*E_x_OB
    E_y2_OG = (1 / E_beta2)*E_y2_OB + (1 / E_beta)*E_y_OB - (1 / E_beta2)*E_y_OB

    varx_OG = E_x2_OG - E_x_OG**2
    vary_OG = E_y2_OG - E_y_OG**2

    if varx_OG <= 0.0 or vary_OG <= 0.0:
        corr = np.nan
    else:
        corr = (E_xy_OG - E_x_OG*E_y_OG) / (np.sqrt(varx_OG) * np.sqrt(vary_OG))

    # collect results
    result = np.array([
        corr,
        interval[0],
        interval[1]
    ])

    return result
