# %%
import pandas as pd
import json

# %%
# %run -i independent_MF_script.py --array_index 0
# Out:
# ...
# 100%|██████████| 100/100 [00:03<00:00, 25.89it/s]

# %%
MF_df = pd.read_csv("ind_MF_0.csv", index_col=0)

# %%
MF_df.value_counts()
# Out:
# ENSG00000278791_d3_c95_status
# OPTIMAL                          84
# INFEASIBLE                       16
# Name: count, dtype: int64
