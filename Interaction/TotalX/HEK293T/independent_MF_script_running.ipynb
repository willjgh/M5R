# %%
import pandas as pd

# %% [markdown]
# ## Running

# %%
# %run -i independent_MF_script.py --array_index 0
# Out:
# ...
# 100%|██████████| 100/100 [00:04<00:00, 22.36it/s]

# %%
# %run -i independent_MF_script.py --array_index 40
# Out:
# ...
# 100%|██████████| 100/100 [00:04<00:00, 23.21it/s]

# %% [markdown]
# ## Results

# %%
MF_0_df = pd.read_csv("ind_MF_0.csv", index_col=0)
MF_40_df = pd.read_csv("ind_MF_40.csv", index_col=0)

# %%
MF_0_df.value_counts()
# Out:
# ENSG00000278791_d3_c95_status
# OPTIMAL                          85
# INFEASIBLE                       15
# Name: count, dtype: int64

# %%
MF_40_df.value_counts()
# Out:
# MIR222_d3_c95_status
# OPTIMAL                 78
# INFEASIBLE              22
# Name: count, dtype: int64
